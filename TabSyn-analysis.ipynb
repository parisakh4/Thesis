# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Config Comparison

# %%
tabsyn_log_df = pd.read_csv("Experiment_logs/experiment_log_tabsyn-.csv")

# Keeping first run per (epochs, batch_size)
tabsyn_best = tabsyn_log_df.groupby(["epochs", "batch_size"], as_index=False).first()

# Chart 1: Batch size on x-axis, grouped by epochs
fig, axes = plt.subplots(1, 2, figsize=(14,6), sharey=True)

sns.scatterplot(
    data=tabsyn_best,
    x="batch_size",
    y="pearson_mae",
    hue="epochs",
    style="epochs",
    s=100,
    palette="tab10",
    ax=axes[0]
)
sns.lineplot(
    data=tabsyn_best,
    x="batch_size",
    y="pearson_mae",
    hue="epochs",
    legend=False,
    alpha=0.8,
    palette="tab10",
    ax=axes[0]
)
axes[0].set_title("Pearson MAE vs Batch Size (TabSyn)")
axes[0].set_xlabel("Batch Size")
axes[0].set_ylabel("MAE")
axes[0].grid(True, linestyle="--", alpha=0.6)

sns.scatterplot(
    data=tabsyn_best,
    x="batch_size",
    y="spearman_mae",
    hue="epochs",
    style="epochs",
    s=100,
    palette="tab10",
    ax=axes[1]
)
sns.lineplot(
    data=tabsyn_best,
    x="batch_size",
    y="spearman_mae",
    hue="epochs",
    legend=False,
    alpha=0.8,
    palette="tab10",
    ax=axes[1]
)
axes[1].set_title("Spearman MAE vs Batch Size (TabSyn)")
axes[1].set_xlabel("Batch Size")
axes[1].set_ylabel("")
axes[1].grid(True, linestyle="--", alpha=0.6)

handles, labels = axes[1].get_legend_handles_labels()
fig.legend(handles, labels, title="Epochs", loc="center right")

plt.tight_layout(rect=[0,0,0.9,1])
plt.show()

# Chart 2: Epochs on x-axis, grouped by batch size 
fig, axes = plt.subplots(1, 2, figsize=(14,6), sharey=True)

sns.scatterplot(
    data=tabsyn_best,
    x="epochs",
    y="pearson_mae",
    hue="batch_size",
    style="batch_size",
    s=100,
    palette="tab10",
    ax=axes[0]
)
sns.lineplot(
    data=tabsyn_best,
    x="epochs",
    y="pearson_mae",
    hue="batch_size",
    legend=False,
    alpha=0.8,
    palette="tab10",
    ax=axes[0]
)
axes[0].set_title("Pearson MAE vs Epochs (TabSyn)")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("MAE")
axes[0].grid(True, linestyle="--", alpha=0.6)

sns.scatterplot(
    data=tabsyn_best,
    x="epochs",
    y="spearman_mae",
    hue="batch_size",
    style="batch_size",
    s=100,
    palette="tab10",
    ax=axes[1]
)
sns.lineplot(
    data=tabsyn_best,
    x="epochs",
    y="spearman_mae",
    hue="batch_size",
    legend=False,
    alpha=0.8,
    palette="tab10",
    ax=axes[1]
)
axes[1].set_title("Spearman MAE vs Epochs (TabSyn)")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("")
axes[1].grid(True, linestyle="--", alpha=0.6)

handles, labels = axes[1].get_legend_handles_labels()
fig.legend(handles, labels, title="Batch Size", loc="center right")

plt.tight_layout(rect=[0,0,0.9,1])
plt.show()

# %% [raw]
# Fake dataset with optimal config analysis- choosing the one close to the median

# %%
tabsyn_log = pd.read_csv("Experiment_logs/experiment_log_tabsyn-.csv")

# Select rows 21–23 
subset = tabsyn_log.iloc[20:23]  

# Compute median Pearson & Spearman MAE
median_mae = subset[["pearson_mae", "spearman_mae"]].median()

print("Median MAE of rows 21–23:")
print(median_mae)
# Out:
# Median MAE of rows 21–23:
# pearson_mae     0.0201
# spearman_mae    0.0161
# dtype: float64

# %%
real_df = pd.read_csv("Data/Real_Datasets/wine_processed_dedu.csv")
tabsyn_df = pd.read_csv('Data/Synthetic_Datasets/TabSyn/tabsyn_run_21.csv')

# %%
print('TabSyn Dataset')
display(tabsyn_df.head())
# Out:
# TabSyn Dataset
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.937495         -0.405457     0.719452       -0.395701  -0.449604
# 1       0.296754          0.364426     0.864331       -0.742694   0.919901
# 2       0.535037         -0.899524    -0.102925        0.783052  -0.417152
# 3      -0.320370         -0.179688     1.179345        0.786316  -0.253646
# 4       0.296754          0.689303    -0.541153        0.534876  -0.826219
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.414233              1.205429 -0.567575  0.009325   0.730751
# 1            -1.326355             -2.195719  0.362827  0.942306   1.066785
# 2             1.101173              0.618476 -0.114803 -0.695330  -0.747799
# 3             0.204386              0.887705  0.525884 -0.674862  -0.451819
# 4             0.152662              0.066763 -0.401378 -0.683701   0.051955
#
#     alcohol   quality   type
# 0 -0.160823 -0.937230  white
# 1  0.593818  1.353228    red
# 2  0.761516  3.386341  white
# 3 -1.334709 -0.937230  white
# 4  0.090724  0.207999  white

# %%
real_num = real_df.select_dtypes(include='number')
tabsyn_num = tabsyn_df.select_dtypes(include='number').drop(columns=['type'], errors='ignore')

real_pearson = real_num.corr(method='pearson')
tabsyn_pearson = tabsyn_num.corr(method='pearson')

plt.figure(figsize=(14, 6))

# Original data
plt.subplot(1, 2, 1)
sns.heatmap(real_pearson, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Real Data - Pearson Correlation')

# Synthesized data
plt.subplot(1, 2, 2)
sns.heatmap(tabsyn_pearson, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title('TabSyn Data - Pearson Correlation')

plt.tight_layout()
plt.show()

# %%
diff_tabsyn = (real_pearson - tabsyn_pearson)
plt.figure(figsize=(10, 8))
sns.heatmap(diff_tabsyn, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Absolute Differences in Pearson Correlation (Real vs TabSyn)")
plt.show()

# %%
# Compute absolute differences 
abs_diff = diff_tabsyn.abs()

# Mean absolute difference (off-diagonal)
vals = abs_diff.values[np.triu_indices_from(abs_diff, k=1)]
print("Mean absolute Pearson diff (TabSyn):", round(vals.mean(), 3))

#  Collect correlation differences with actual values 
records = []
for i, j in zip(*np.triu_indices_from(abs_diff, k=1)):
    records.append({
        "Metric": "Pearson",
        "Pair": f"{diff_tabsyn.columns[i]} – {diff_tabsyn.columns[j]}",
        "Real": real_pearson.iloc[i, j],
        "Fake": tabsyn_pearson.iloc[i, j],
        "Abs Δ": abs_diff.iloc[i, j]
    })

#  Sort and take top 3 
tabsyn_pearson_top3 = sorted(records, key=lambda x: x["Abs Δ"], reverse=True)[:3]

#  Pretty print standalone table 
col_width = 25
header = f"{'Pair':<{col_width}} | {'Real':>7} | {'Fake':>7} | {'Abs Δ':>6}"
print("\nTop 3 biggest Pearson shifts (TabSyn):\n")
print("-" * len(header))
print(header)
print("-" * len(header))
for r in tabsyn_pearson_top3:
    print(f"{r['Pair']:<{col_width}} | "
          f"{r['Real']:>7.2f} | "
          f"{r['Fake']:>7.2f} | "
          f"{r['Abs Δ']:>6.2f}")
print("-" * len(header))
# Out:
# Mean absolute Pearson diff (TabSyn): 0.018
#
# Top 3 biggest Pearson shifts (TabSyn):
#
# ------------------------------------------------------
# Pair                      |    Real |    Fake |  Abs Δ
# ------------------------------------------------------
# pH – sulphates            |    0.17 |    0.22 |   0.06
# chlorides – sulphates     |    0.41 |    0.36 |   0.05
# residual sugar – alcohol  |   -0.27 |   -0.32 |   0.04
# ------------------------------------------------------

# %%
#  Spearman correlation matrices 
real_spear = real_num.corr(method="spearman")
tabsyn_spear  = tabsyn_num.corr(method="spearman")

# Plot side by side with numbers (smaller font, 2 decimals)
fig, axes = plt.subplots(1,2,figsize=(12,5), tight_layout=True)
sns.heatmap(real_spear, vmin=-1, vmax=1, center=0, cmap="vlag",
            annot=True, fmt=".2f", annot_kws={"size":8}, ax=axes[0])
axes[0].set_title("Real Data — Spearman")

sns.heatmap(tabsyn_spear, vmin=-1, vmax=1, center=0, cmap="vlag",
            annot=True, fmt=".2f", annot_kws={"size":8}, ax=axes[1])
axes[1].set_title("TabSyn Synthetic — Spearman")

plt.show()

# Compute & plot absolute‐difference
diff_spear = (tabsyn_spear - real_spear).abs().round(2)
plt.figure(figsize=(6,5))
sns.heatmap(diff_spear, vmin=0, vmax=diff_spear.values.max(), cmap="rocket",
            annot=True, fmt=".2f", annot_kws={"size":8})
plt.title("│Δ Spearman│ (Real vs Tabsyn)")
plt.tight_layout()
plt.show()

# %%
i,j = np.triu_indices_from(diff_spear, k=1)
print("Mean │Δ Spearman│:", diff_spear.values[i,j].mean().round(3))
# Out:
# Mean │Δ Spearman│: 0.015

# %%
# Collect upper-triangle pairs 
i, j = np.triu_indices_from(diff_spear, k=1)
pairs = [
    {
        "Metric": "Spearman",
        "Pair": f"{diff_spear.columns[i_]} – {diff_spear.columns[j_]}",
        "Real": real_spear.values[i_, j_],
        "Fake": tabsyn_spear.values[i_, j_],
        "Abs Δ": diff_spear.values[i_, j_]
    }
    for i_, j_ in zip(i, j)
]

#  Sort and take top 3 
tabsyn_spear_top3 = sorted(pairs, key=lambda x: x["Abs Δ"], reverse=True)[:3]

# Pretty print standalone table 
col_width = 25
header = f"{'Pair':<{col_width}} | {'Real':>7} | {'Fake':>7} | {'Abs Δ':>6}"
print("\nTop 3 biggest Spearman shifts (TabSyn):\n")
print("-" * len(header))
print(header)
print("-" * len(header))
for r in tabsyn_spear_top3:
    print(f"{r['Pair']:<{col_width}} | "
          f"{r['Real']:>7.2f} | "
          f"{r['Fake']:>7.2f} | "
          f"{r['Abs Δ']:>6.2f}")
print("-" * len(header))
# Out:
# Top 3 biggest Spearman shifts (TabSyn):
#
# ------------------------------------------------------
# Pair                      |    Real |    Fake |  Abs Δ
# ------------------------------------------------------
# volatile acidity – residual sugar |   -0.02 |   -0.07 |   0.05
# residual sugar – alcohol  |   -0.27 |   -0.31 |   0.05
# volatile acidity – alcohol |   -0.06 |   -0.02 |   0.04
# ------------------------------------------------------

# %% [markdown]
# Distance correlation

# %%
import numpy as np

# 1- fast distance covariance
def fast_dcov(x, y):
    x = np.asarray(x).flatten()
    y = np.asarray(y).flatten()
    n = len(x)
    
    # Sort x
    idx = np.argsort(x)
    x = x[idx]
    y = y[idx]
    
    # Row sums of distance matrix of x
    si = np.cumsum(x)
    s = si[-1]
    ax = (-(n-2) + 2*np.arange(n)) * x + (s - 2*si)
    
    # Weight matrix
    v = np.column_stack((x, y, x*y))
    nw = v.shape[1]
    
    idx_buf = np.zeros((n, 2), dtype=int)
    idx_buf[:, 0] = np.arange(n)
    
    iv1 = np.zeros(n)
    iv2 = np.zeros(n)
    iv3 = np.zeros(n)
    iv4 = np.zeros(n)
    
    i = 1
    r, s_idx = 0, 1
    while i < n:
        gap = 2 * i
        k = 0
        idxr = idx_buf[:, r]
        csumv = np.vstack([np.zeros((1, nw)), np.cumsum(v[idxr], axis=0)])
        
        for j in range(0, n, gap):
            st1 = j
            e1 = min(st1 + i - 1, n-1)
            st2 = j + i
            e2 = min(st2 + i - 1, n-1)
            
            while st1 <= e1 and st2 <= e2:
                idx1 = idxr[st1]
                idx2 = idxr[st2]
                if y[idx1] >= y[idx2]:
                    idx_buf[k, s_idx] = idx1
                    st1 += 1
                else:
                    idx_buf[k, s_idx] = idx2
                    iv1[idx2] += e1 - st1 + 1
                    iv2[idx2] += csumv[e1+1, 0] - csumv[st1, 0]
                    iv3[idx2] += csumv[e1+1, 1] - csumv[st1, 1]
                    iv4[idx2] += csumv[e1+1, 2] - csumv[st1, 2]
                    st2 += 1
                k += 1
            
            # Copy leftovers
            if st1 <= e1:
                idx_buf[k:k+e1-st1+1, s_idx] = idxr[st1:e1+1]
                k += e1-st1+1
            elif st2 <= e2:
                idx_buf[k:k+e2-st2+1, s_idx] = idxr[st2:e2+1]
                k += e2-st2+1
                
        i = gap
        r, s_idx = s_idx, r
    
    covterm = n * np.sum((x - np.mean(x)) * (y - np.mean(y)))
    c1 = np.dot(iv1, v[:, 2])
    c2 = np.sum(iv4)
    c3 = np.dot(iv2, y)
    c4 = np.dot(iv3, x)
    d = 4 * ((c1 + c2) - (c3 + c4)) - 2 * covterm
    
    ySorted = y[idx_buf[n-1::-1, r]]
    si_y = np.cumsum(ySorted)
    s_y = si_y[-1]
    by = np.zeros(n)
    by[idx_buf[n-1::-1, r]] = (-(n-2) + 2*np.arange(n)) * ySorted + (s_y - 2*si_y)
    
    nsq = n * n
    ncb = nsq * n
    nq = ncb * n
    term1 = d / nsq
    term2 = 2 * np.dot(ax, by) / ncb
    term3 = np.sum(ax) * np.sum(by) / nq
    
    covsq = (term1 + term3) - term2
    return covsq

#2 - distance correlation matrix for tabular data
def distance_correlation_matrix(data):
    data = np.asarray(data)
    n_features = data.shape[1]
    dcor_mat = np.zeros((n_features, n_features))

    for i in range(n_features):
        for j in range(i, n_features):
            x = data[:, i]
            y = data[:, j]
            dcov_xy = fast_dcov(x, y)
            dcov_xx = fast_dcov(x, x)
            dcov_yy = fast_dcov(y, y)
            dcor = np.sqrt(dcov_xy / np.sqrt(dcov_xx * dcov_yy)) if dcov_xx > 0 and dcov_yy > 0 else 0
            dcor_mat[i, j] = dcor
            dcor_mat[j, i] = dcor

    return dcor_mat

# %%
# Compute distance correlation matrices for real and fake 
real_dcor = distance_correlation_matrix(real_num.values)
fake_dcor = distance_correlation_matrix(tabsyn_num.values)

real_dcor = pd.DataFrame(real_dcor, index=real_num.columns, columns=real_num.columns)
fake_dcor = pd.DataFrame(fake_dcor, index=tabsyn_num.columns, columns=tabsyn_num.columns)

# Plot side by side 
fig, axes = plt.subplots(1, 2, figsize=(12,5), tight_layout=True)
sns.heatmap(real_dcor, vmin=0, vmax=1, cmap="viridis", annot=True, fmt=".2f", annot_kws={"size":8}, ax=axes[0])
axes[0].set_title("Real Data — Distance Corr")

sns.heatmap(fake_dcor, vmin=0, vmax=1, cmap="viridis", annot=True, fmt=".2f", annot_kws={"size":8}, ax=axes[1])
axes[1].set_title("TabSyn Synthetic — Distance Corr")

plt.show()

#  Difference heatmap 
diff_dcor = (real_dcor - fake_dcor).abs().round(3)
plt.figure(figsize=(6,5))
sns.heatmap(diff_dcor, vmin=0, vmax=diff_dcor.values.max(), cmap="rocket",
            annot=True, fmt=".2f", annot_kws={"size":8})
plt.title("│Δ Distance Corr│ (Real vs TVAE)")
plt.tight_layout()
plt.show()

# %%
# Extract top 3 biggest shifts 
i, j = np.triu_indices_from(diff_dcor, k=1)
pairs = [
    {
        "Metric": "Distance Corr",
        "Pair": f"{diff_dcor.columns[i_]} – {diff_dcor.columns[j_]}",
        "Real": real_dcor.values[i_, j_],
        "Fake": fake_dcor.values[i_, j_],
        "Abs Δ": diff_dcor.values[i_, j_]
    }
    for i_, j_ in zip(i, j)
]

#  Sort and take top 3 
tabsyn_dcor_top3 = sorted(pairs, key=lambda x: x["Abs Δ"], reverse=True)[:3]

#  print standalone table 
col_width = 25
header = f"{'Pair':<{col_width}} | {'Real':>7} | {'Fake':>7} | {'Abs Δ':>6}"
print("\nTop 3 biggest Distance Corr shifts (TabSyn):\n")
print("-" * len(header))
print(header)
print("-" * len(header))
for r in tabsyn_dcor_top3:
    print(f"{r['Pair']:<{col_width}} | "
          f"{r['Real']:>7.2f} | "
          f"{r['Fake']:>7.2f} | "
          f"{r['Abs Δ']:>6.2f}")
print("-" * len(header))
# Out:
# Top 3 biggest Distance Corr shifts (TabSyn):
#
# ------------------------------------------------------
# Pair                      |    Real |    Fake |  Abs Δ
# ------------------------------------------------------
# residual sugar – pH       |    0.24 |    0.28 |   0.04
# residual sugar – alcohol  |    0.28 |    0.31 |   0.04
# fixed acidity – volatile acidity |    0.24 |    0.27 |   0.03
# ------------------------------------------------------

# %%
#  MAE for distance correlation 
vals = diff_dcor.values[np.triu_indices_from(diff_dcor, k=1)]
mae_dcor = vals.mean()
print("Mean absolute Distance Corr diff (MAE):", round(mae_dcor, 3))
# Out:
# Mean absolute Distance Corr diff (MAE): 0.013

# %%
from tabulate import tabulate
import pandas as pd

def pretty_print_tool_table(tool_name, metrics_dict):
    rows = []
    for metric, records in metrics_dict.items():
        df = pd.DataFrame(records)
        df = df[["Pair", "Real", "Fake", "Abs Δ"]]

        for idx, row in df.iterrows():
            rows.append([
                tool_name if idx == df.index[0] and metric == list(metrics_dict.keys())[0] else "",
                metric if idx == df.index[0] else "",
                row["Pair"],
                f"{row['Real']:.3f}",
                f"{row['Fake']:.3f}",
                f"{row['Abs Δ']:.3f}"
            ])
        # separator between metrics
        rows.append(["", "-"*10, "-"*20, "-"*5, "-"*5, "-"*5])

    headers = ["Tool", "Metric", "Pair", "Real", "Fake", "Abs Δ"]
    print(tabulate(rows, headers=headers, tablefmt="pretty"))

# Collect TabSyn top-3 into dict 
tabsyn_top3 = {
    "Pearson": tabsyn_pearson_top3,
    "Spearman": tabsyn_spear_top3,
    "Distance Corr": tabsyn_dcor_top3
}

# Print grouped table for TabSyn
pretty_print_tool_table("TabSyn", tabsyn_top3)
# Out:
# +--------+---------------+-----------------------------------+--------+--------+-------+
# |  Tool  |    Metric     |               Pair                |  Real  |  Fake  | Abs Δ |
# +--------+---------------+-----------------------------------+--------+--------+-------+
# | TabSyn |    Pearson    |          pH – sulphates           | 0.168  | 0.224  | 0.056 |
# |        |               |       chlorides – sulphates       | 0.406  | 0.360  | 0.046 |
# |        |               |     residual sugar – alcohol      | -0.272 | -0.316 | 0.043 |
# |        |  ----------   |       --------------------        | -----  | -----  | ----- |
# |        |   Spearman    | volatile acidity – residual sugar | -0.022 | -0.070 | 0.050 |
# |        |               |     residual sugar – alcohol      | -0.267 | -0.314 | 0.050 |
# |        |               |    volatile acidity – alcohol     | -0.062 | -0.025 | 0.040 |
# |        |  ----------   |       --------------------        | -----  | -----  | ----- |
# |        | Distance Corr |        residual sugar – pH        | 0.244  | 0.283  | 0.039 |
# |        |               |     residual sugar – alcohol      | 0.278  | 0.314  | 0.036 |
# |        |               | fixed acidity – volatile acidity  | 0.236  | 0.267  | 0.030 |
# |        |  ----------   |       --------------------        | -----  | -----  | ----- |
# +--------+---------------+-----------------------------------+--------+--------+-------+

# %%
features = ["volatile acidity", "residual sugar", "alcohol"]

fig, axes = plt.subplots(1, len(features), figsize=(4*len(features), 4), tight_layout=True)

for idx, feat in enumerate(features):
    sns.kdeplot(real_num[feat], fill=True, color="blue", label="Real", ax=axes[idx], alpha=0.4)
    sns.kdeplot(tabsyn_num[feat], fill=True, color="red", label="Fake", ax=axes[idx], alpha=0.4)
    axes[idx].set_title(feat)
    axes[idx].legend()

plt.suptitle("Overlay Distributions (Real vs Synthetic)", fontsize=14, y=1.05)
plt.show()

# %%
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

pairs = [
    ("pH", "sulphates"),
    ("volatile acidity", "residual sugar")
]

fig, axes = plt.subplots(1, len(pairs), figsize=(6*len(pairs), 5), tight_layout=True)

for idx, (f1, f2) in enumerate(pairs):
    # --- Scatter overlay ---
    axes[idx].scatter(real_num[f1], real_num[f2], alpha=0.3, color="blue", label="Real")
    axes[idx].scatter(tabsyn_num[f1], tabsyn_num[f2], alpha=0.3, color="red", label="Fake")

    axes[idx].set_title(f"{f1} vs {f2}")
    axes[idx].set_xlabel(f1)
    axes[idx].set_ylabel(f2)

    # --- Compute correlations ---
    pear_real = real_num[[f1, f2]].corr(method="pearson").iloc[0,1]
    pear_fake = tabsyn_num[[f1, f2]].corr(method="pearson").iloc[0,1]
    spear_real, _ = spearmanr(real_num[f1], real_num[f2])
    spear_fake, _ = spearmanr(tabsyn_num[f1], tabsyn_num[f2])

    # --- Annotate on plot ---
    textstr = (f"Pearson: real={pear_real:.3f}, fake={pear_fake:.3f}\n"
               f"Spearman: real={spear_real:.3f}, fake={spear_fake:.3f}")
    axes[idx].text(0.05, 0.95, textstr, transform=axes[idx].transAxes,
                   fontsize=9, va="top", ha="left",
                   bbox=dict(boxstyle="round", facecolor="white", alpha=0.7))

    axes[idx].legend()

plt.suptitle("TabSyn: Overlay Joint Distributions with Correlations", fontsize=14, y=1.02)
plt.show()
